# %%
import os
from PIL import Image

def resize_and_crop_image(image, target_size):
    """
    Resizes and crops an image to fit the target size while maintaining the aspect ratio.

    :param image: The original PIL image object.
    :param target_size: A tuple of (width, height).
    :return: The resized and cropped image.
    """
    target_width, target_height = target_size
    img_width, img_height = image.size

    # Calculate the scaling factor
    scale = max(target_width / img_width, target_height / img_height)

    # Resize the image while maintaining aspect ratio
    new_width = int(img_width * scale)
    new_height = int(img_height * scale)
    image = image.resize((new_width, new_height), Image.Resampling.LANCZOS)

    # Crop the image to the center
    left = (new_width - target_width) / 2
    top = (new_height - target_height) / 2
    right = left + target_width
    bottom = top + target_height

    return image.crop((left, top, right, bottom))


def resize_and_organize_images(source_folder, sizes):
    """
    Organizes images into folders based on size, resizing and cropping them.

    :param source_folder: The folder containing the images.
    :param sizes: A list of target sizes (width, height).
    """
    if not os.path.exists(source_folder):
        print(f"Der Ordner {source_folder} existiert nicht.")
        return

    for size in sizes:
        folder_name = f"{size[0]}x{size[1]}"
        target_folder = os.path.join(source_folder, folder_name)

        # Create the target folder if it doesn't exist
        if not os.path.exists(target_folder):
            os.makedirs(target_folder)

        for filename in os.listdir(source_folder):
            file_path = os.path.join(source_folder, filename)

            # Skip folders and non-image files
            if os.path.isfile(file_path) and filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):
                try:
                    with Image.open(file_path) as img:
                        resized_cropped_img = resize_and_crop_image(img, size)

                        # Save the resized and cropped image to the target folder
                        target_path = os.path.join(target_folder, filename)
                        resized_cropped_img.save(target_path)

                        print(f"{filename} wurde in {folder_name} gespeichert.")
                except Exception as e:
                    print(f"Fehler beim Verarbeiten von {filename}: {e}")

if __name__ == "__main__":
    # Path to your source folder with images
    source_folder = "gt"

    # Define the desired sizes
    sizes = [(115, 115),(115, 165),(115, 215),(115, 265),(165, 115),(165, 165),(165, 215),(165, 265),(215, 115), (215, 165), (215, 215), (215, 265), (265, 115), (265, 165), (265, 215), (265, 265)  ]

    resize_and_organize_images(source_folder, sizes)
# Out:
# barret.jpg wurde in 115x115 gespeichert.
# buch.jpg wurde in 115x115 gespeichert.
# buch2.jpg wurde in 115x115 gespeichert.
# haus.jpg wurde in 115x115 gespeichert.
# haus2.jpg wurde in 115x115 gespeichert.
# haus3.JPG wurde in 115x115 gespeichert.
# hegelhead.jpg wurde in 115x115 gespeichert.
# hegelhead2.jpeg wurde in 115x115 gespeichert.
# hegelhead3.jpg wurde in 115x115 gespeichert.
# holz1.jpg wurde in 115x115 gespeichert.
# holz2.jpg wurde in 115x115 gespeichert.
# holz3.jpg wurde in 115x115 gespeichert.
# holz4.jpg wurde in 115x115 gespeichert.
# logo.jpg wurde in 115x115 gespeichert.
# logo2.jpg wurde in 115x115 gespeichert.
# muenze.jpg wurde in 115x115 gespeichert.
# muenze2.jpg wurde in 115x115 gespeichert.
# schlussstein.jpg wurde in 115x115 gespeichert.
# schlussstein2.jpg wurde in 115x115 gespeichert.
# stories-02.jpg wurde in 115x115 gespeichert.
# stories-03.jpg wurde in 115x115 gespeichert.
# tri.jpg wurde in 115x115 gespeichert.
# barret.jpg wurde in 115x165 gespeichert.
# buch.jpg wurde in 115x165 gespeichert.
# buch2.jpg wurde in 115x165 gespeichert.
# haus.jpg wurde in 115x165 gespeichert.
# haus2.jpg wurde in 115x165 gespeichert.
# haus3.JPG wurde in 115x165 gespeichert.
# hegelhead.jpg wurde in 115x165 gespeichert.
# hegelhead2.jpeg wurde in 115x165 gespeichert.
# hegelhead3.jpg wurde in 115x165 gespeichert.
# holz1.jpg wurde in 115x165 gespeichert.
# holz2.jpg wurde in 115x165 gespeichert.
# holz3.jpg wurde in 115x165 gespeichert.
# holz4.jpg wurde in 115x165 gespeichert.
# logo.jpg wurde in 115x165 gespeichert.
# logo2.jpg wurde in 115x165 gespeichert.
# muenze.jpg wurde in 115x165 gespeichert.
# muenze2.jpg wurde in 115x165 gespeichert.
# schlussstein.jpg wurde in 115x165 gespeichert.
# schlussstein2.jpg wurde in 115x165 gespeichert.
# stories-02.jpg wurde in 115x165 gespeichert.
# stories-03.jpg wurde in 115x165 gespeichert.
# tri.jpg wurde in 115x165 gespeichert.
# barret.jpg wurde in 115x215 gespeichert.
# buch.jpg wurde in 115x215 gespeichert.
# buch2.jpg wurde in 115x215 gespeichert.
# haus.jpg wurde in 115x215 gespeichert.
# haus2.jpg wurde in 115x215 gespeichert.
# haus3.JPG wurde in 115x215 gespeichert.
# hegelhead.jpg wurde in 115x215 gespeichert.
# hegelhead2.jpeg wurde in 115x215 gespeichert.
# hegelhead3.jpg wurde in 115x215 gespeichert.
# holz1.jpg wurde in 115x215 gespeichert.
# holz2.jpg wurde in 115x215 gespeichert.
# holz3.jpg wurde in 115x215 gespeichert.
# holz4.jpg wurde in 115x215 gespeichert.
# logo.jpg wurde in 115x215 gespeichert.
# logo2.jpg wurde in 115x215 gespeichert.
# muenze.jpg wurde in 115x215 gespeichert.
# muenze2.jpg wurde in 115x215 gespeichert.
# schlussstein.jpg wurde in 115x215 gespeichert.
# schlussstein2.jpg wurde in 115x215 gespeichert.
# stories-02.jpg wurde in 115x215 gespeichert.
# stories-03.jpg wurde in 115x215 gespeichert.
# tri.jpg wurde in 115x215 gespeichert.
# barret.jpg wurde in 115x265 gespeichert.
# buch.jpg wurde in 115x265 gespeichert.
# buch2.jpg wurde in 115x265 gespeichert.
# haus.jpg wurde in 115x265 gespeichert.
# haus2.jpg wurde in 115x265 gespeichert.
# haus3.JPG wurde in 115x265 gespeichert.
# hegelhead.jpg wurde in 115x265 gespeichert.
# hegelhead2.jpeg wurde in 115x265 gespeichert.
# hegelhead3.jpg wurde in 115x265 gespeichert.
# holz1.jpg wurde in 115x265 gespeichert.
# holz2.jpg wurde in 115x265 gespeichert.
# holz3.jpg wurde in 115x265 gespeichert.
# holz4.jpg wurde in 115x265 gespeichert.
# logo.jpg wurde in 115x265 gespeichert.
# logo2.jpg wurde in 115x265 gespeichert.
# muenze.jpg wurde in 115x265 gespeichert.
# muenze2.jpg wurde in 115x265 gespeichert.
# schlussstein.jpg wurde in 115x265 gespeichert.
# schlussstein2.jpg wurde in 115x265 gespeichert.
# stories-02.jpg wurde in 115x265 gespeichert.
# stories-03.jpg wurde in 115x265 gespeichert.
# tri.jpg wurde in 115x265 gespeichert.
# barret.jpg wurde in 165x115 gespeichert.
# buch.jpg wurde in 165x115 gespeichert.
# buch2.jpg wurde in 165x115 gespeichert.
# haus.jpg wurde in 165x115 gespeichert.
# haus2.jpg wurde in 165x115 gespeichert.
# haus3.JPG wurde in 165x115 gespeichert.
# hegelhead.jpg wurde in 165x115 gespeichert.
# hegelhead2.jpeg wurde in 165x115 gespeichert.
# hegelhead3.jpg wurde in 165x115 gespeichert.
# holz1.jpg wurde in 165x115 gespeichert.
# holz2.jpg wurde in 165x115 gespeichert.
# holz3.jpg wurde in 165x115 gespeichert.
# holz4.jpg wurde in 165x115 gespeichert.
# logo.jpg wurde in 165x115 gespeichert.
# logo2.jpg wurde in 165x115 gespeichert.
# muenze.jpg wurde in 165x115 gespeichert.
# muenze2.jpg wurde in 165x115 gespeichert.
# schlussstein.jpg wurde in 165x115 gespeichert.
# schlussstein2.jpg wurde in 165x115 gespeichert.
# stories-02.jpg wurde in 165x115 gespeichert.
# stories-03.jpg wurde in 165x115 gespeichert.
# tri.jpg wurde in 165x115 gespeichert.
# barret.jpg wurde in 165x165 gespeichert.
# buch.jpg wurde in 165x165 gespeichert.
# buch2.jpg wurde in 165x165 gespeichert.
# haus.jpg wurde in 165x165 gespeichert.
# haus2.jpg wurde in 165x165 gespeichert.
# haus3.JPG wurde in 165x165 gespeichert.
# hegelhead.jpg wurde in 165x165 gespeichert.
# hegelhead2.jpeg wurde in 165x165 gespeichert.
# hegelhead3.jpg wurde in 165x165 gespeichert.
# holz1.jpg wurde in 165x165 gespeichert.
# holz2.jpg wurde in 165x165 gespeichert.
# holz3.jpg wurde in 165x165 gespeichert.
# holz4.jpg wurde in 165x165 gespeichert.
# logo.jpg wurde in 165x165 gespeichert.
# logo2.jpg wurde in 165x165 gespeichert.
# muenze.jpg wurde in 165x165 gespeichert.
# muenze2.jpg wurde in 165x165 gespeichert.
# schlussstein.jpg wurde in 165x165 gespeichert.
# schlussstein2.jpg wurde in 165x165 gespeichert.
# stories-02.jpg wurde in 165x165 gespeichert.
# stories-03.jpg wurde in 165x165 gespeichert.
# tri.jpg wurde in 165x165 gespeichert.
# barret.jpg wurde in 165x215 gespeichert.
# buch.jpg wurde in 165x215 gespeichert.
# buch2.jpg wurde in 165x215 gespeichert.
# haus.jpg wurde in 165x215 gespeichert.
# haus2.jpg wurde in 165x215 gespeichert.
# haus3.JPG wurde in 165x215 gespeichert.
# hegelhead.jpg wurde in 165x215 gespeichert.
# hegelhead2.jpeg wurde in 165x215 gespeichert.
# hegelhead3.jpg wurde in 165x215 gespeichert.
# holz1.jpg wurde in 165x215 gespeichert.
# holz2.jpg wurde in 165x215 gespeichert.
# holz3.jpg wurde in 165x215 gespeichert.
# holz4.jpg wurde in 165x215 gespeichert.
# logo.jpg wurde in 165x215 gespeichert.
# logo2.jpg wurde in 165x215 gespeichert.
# muenze.jpg wurde in 165x215 gespeichert.
# muenze2.jpg wurde in 165x215 gespeichert.
# schlussstein.jpg wurde in 165x215 gespeichert.
# schlussstein2.jpg wurde in 165x215 gespeichert.
# stories-02.jpg wurde in 165x215 gespeichert.
# stories-03.jpg wurde in 165x215 gespeichert.
# tri.jpg wurde in 165x215 gespeichert.
# barret.jpg wurde in 165x265 gespeichert.
# buch.jpg wurde in 165x265 gespeichert.
# buch2.jpg wurde in 165x265 gespeichert.
# haus.jpg wurde in 165x265 gespeichert.
# haus2.jpg wurde in 165x265 gespeichert.
# haus3.JPG wurde in 165x265 gespeichert.
# hegelhead.jpg wurde in 165x265 gespeichert.
# hegelhead2.jpeg wurde in 165x265 gespeichert.
# hegelhead3.jpg wurde in 165x265 gespeichert.
# holz1.jpg wurde in 165x265 gespeichert.
# holz2.jpg wurde in 165x265 gespeichert.
# holz3.jpg wurde in 165x265 gespeichert.
# holz4.jpg wurde in 165x265 gespeichert.
# logo.jpg wurde in 165x265 gespeichert.
# logo2.jpg wurde in 165x265 gespeichert.
# muenze.jpg wurde in 165x265 gespeichert.
# muenze2.jpg wurde in 165x265 gespeichert.
# schlussstein.jpg wurde in 165x265 gespeichert.
# schlussstein2.jpg wurde in 165x265 gespeichert.
# stories-02.jpg wurde in 165x265 gespeichert.
# stories-03.jpg wurde in 165x265 gespeichert.
# tri.jpg wurde in 165x265 gespeichert.
# barret.jpg wurde in 215x115 gespeichert.
# buch.jpg wurde in 215x115 gespeichert.
# buch2.jpg wurde in 215x115 gespeichert.
# haus.jpg wurde in 215x115 gespeichert.
# haus2.jpg wurde in 215x115 gespeichert.
# haus3.JPG wurde in 215x115 gespeichert.
# hegelhead.jpg wurde in 215x115 gespeichert.
# hegelhead2.jpeg wurde in 215x115 gespeichert.
# hegelhead3.jpg wurde in 215x115 gespeichert.
# holz1.jpg wurde in 215x115 gespeichert.
# holz2.jpg wurde in 215x115 gespeichert.
# holz3.jpg wurde in 215x115 gespeichert.
# holz4.jpg wurde in 215x115 gespeichert.
# logo.jpg wurde in 215x115 gespeichert.
# logo2.jpg wurde in 215x115 gespeichert.
# muenze.jpg wurde in 215x115 gespeichert.
# muenze2.jpg wurde in 215x115 gespeichert.
# schlussstein.jpg wurde in 215x115 gespeichert.
# schlussstein2.jpg wurde in 215x115 gespeichert.
# stories-02.jpg wurde in 215x115 gespeichert.
# stories-03.jpg wurde in 215x115 gespeichert.
# tri.jpg wurde in 215x115 gespeichert.
# barret.jpg wurde in 215x165 gespeichert.
# buch.jpg wurde in 215x165 gespeichert.
# buch2.jpg wurde in 215x165 gespeichert.
# haus.jpg wurde in 215x165 gespeichert.
# haus2.jpg wurde in 215x165 gespeichert.
# haus3.JPG wurde in 215x165 gespeichert.
# hegelhead.jpg wurde in 215x165 gespeichert.
# hegelhead2.jpeg wurde in 215x165 gespeichert.
# hegelhead3.jpg wurde in 215x165 gespeichert.
# holz1.jpg wurde in 215x165 gespeichert.
# holz2.jpg wurde in 215x165 gespeichert.
# holz3.jpg wurde in 215x165 gespeichert.
# holz4.jpg wurde in 215x165 gespeichert.
# logo.jpg wurde in 215x165 gespeichert.
# logo2.jpg wurde in 215x165 gespeichert.
# muenze.jpg wurde in 215x165 gespeichert.
# muenze2.jpg wurde in 215x165 gespeichert.
# schlussstein.jpg wurde in 215x165 gespeichert.
# schlussstein2.jpg wurde in 215x165 gespeichert.
# stories-02.jpg wurde in 215x165 gespeichert.
# stories-03.jpg wurde in 215x165 gespeichert.
# tri.jpg wurde in 215x165 gespeichert.
# barret.jpg wurde in 215x215 gespeichert.
# buch.jpg wurde in 215x215 gespeichert.
# buch2.jpg wurde in 215x215 gespeichert.
# haus.jpg wurde in 215x215 gespeichert.
# haus2.jpg wurde in 215x215 gespeichert.
# haus3.JPG wurde in 215x215 gespeichert.
# hegelhead.jpg wurde in 215x215 gespeichert.
# hegelhead2.jpeg wurde in 215x215 gespeichert.
# hegelhead3.jpg wurde in 215x215 gespeichert.
# holz1.jpg wurde in 215x215 gespeichert.
# holz2.jpg wurde in 215x215 gespeichert.
# holz3.jpg wurde in 215x215 gespeichert.
# holz4.jpg wurde in 215x215 gespeichert.
# logo.jpg wurde in 215x215 gespeichert.
# logo2.jpg wurde in 215x215 gespeichert.
# muenze.jpg wurde in 215x215 gespeichert.
# muenze2.jpg wurde in 215x215 gespeichert.
# schlussstein.jpg wurde in 215x215 gespeichert.
# schlussstein2.jpg wurde in 215x215 gespeichert.
# stories-02.jpg wurde in 215x215 gespeichert.
# stories-03.jpg wurde in 215x215 gespeichert.
# tri.jpg wurde in 215x215 gespeichert.
# barret.jpg wurde in 215x265 gespeichert.
# buch.jpg wurde in 215x265 gespeichert.
# buch2.jpg wurde in 215x265 gespeichert.
# haus.jpg wurde in 215x265 gespeichert.
# haus2.jpg wurde in 215x265 gespeichert.
# haus3.JPG wurde in 215x265 gespeichert.
# hegelhead.jpg wurde in 215x265 gespeichert.
# hegelhead2.jpeg wurde in 215x265 gespeichert.
# hegelhead3.jpg wurde in 215x265 gespeichert.
# holz1.jpg wurde in 215x265 gespeichert.
# holz2.jpg wurde in 215x265 gespeichert.
# holz3.jpg wurde in 215x265 gespeichert.
# holz4.jpg wurde in 215x265 gespeichert.
# logo.jpg wurde in 215x265 gespeichert.
# logo2.jpg wurde in 215x265 gespeichert.
# muenze.jpg wurde in 215x265 gespeichert.
# muenze2.jpg wurde in 215x265 gespeichert.
# schlussstein.jpg wurde in 215x265 gespeichert.
# schlussstein2.jpg wurde in 215x265 gespeichert.
# stories-02.jpg wurde in 215x265 gespeichert.
# stories-03.jpg wurde in 215x265 gespeichert.
# tri.jpg wurde in 215x265 gespeichert.
# barret.jpg wurde in 265x115 gespeichert.
# buch.jpg wurde in 265x115 gespeichert.
# buch2.jpg wurde in 265x115 gespeichert.
# haus.jpg wurde in 265x115 gespeichert.
# haus2.jpg wurde in 265x115 gespeichert.
# haus3.JPG wurde in 265x115 gespeichert.
# hegelhead.jpg wurde in 265x115 gespeichert.
# hegelhead2.jpeg wurde in 265x115 gespeichert.
# hegelhead3.jpg wurde in 265x115 gespeichert.
# holz1.jpg wurde in 265x115 gespeichert.
# holz2.jpg wurde in 265x115 gespeichert.
# holz3.jpg wurde in 265x115 gespeichert.
# holz4.jpg wurde in 265x115 gespeichert.
# logo.jpg wurde in 265x115 gespeichert.
# logo2.jpg wurde in 265x115 gespeichert.
# muenze.jpg wurde in 265x115 gespeichert.
# muenze2.jpg wurde in 265x115 gespeichert.
# schlussstein.jpg wurde in 265x115 gespeichert.
# schlussstein2.jpg wurde in 265x115 gespeichert.
# stories-02.jpg wurde in 265x115 gespeichert.
# stories-03.jpg wurde in 265x115 gespeichert.
# tri.jpg wurde in 265x115 gespeichert.
# barret.jpg wurde in 265x165 gespeichert.
# buch.jpg wurde in 265x165 gespeichert.
# buch2.jpg wurde in 265x165 gespeichert.
# haus.jpg wurde in 265x165 gespeichert.
# haus2.jpg wurde in 265x165 gespeichert.
# haus3.JPG wurde in 265x165 gespeichert.
# hegelhead.jpg wurde in 265x165 gespeichert.
# hegelhead2.jpeg wurde in 265x165 gespeichert.
# hegelhead3.jpg wurde in 265x165 gespeichert.
# holz1.jpg wurde in 265x165 gespeichert.
# holz2.jpg wurde in 265x165 gespeichert.
# holz3.jpg wurde in 265x165 gespeichert.
# holz4.jpg wurde in 265x165 gespeichert.
# logo.jpg wurde in 265x165 gespeichert.
# logo2.jpg wurde in 265x165 gespeichert.
# muenze.jpg wurde in 265x165 gespeichert.
# muenze2.jpg wurde in 265x165 gespeichert.
# schlussstein.jpg wurde in 265x165 gespeichert.
# schlussstein2.jpg wurde in 265x165 gespeichert.
# stories-02.jpg wurde in 265x165 gespeichert.
# stories-03.jpg wurde in 265x165 gespeichert.
# tri.jpg wurde in 265x165 gespeichert.
# barret.jpg wurde in 265x215 gespeichert.
# buch.jpg wurde in 265x215 gespeichert.
# buch2.jpg wurde in 265x215 gespeichert.
# haus.jpg wurde in 265x215 gespeichert.
# haus2.jpg wurde in 265x215 gespeichert.
# haus3.JPG wurde in 265x215 gespeichert.
# hegelhead.jpg wurde in 265x215 gespeichert.
# hegelhead2.jpeg wurde in 265x215 gespeichert.
# hegelhead3.jpg wurde in 265x215 gespeichert.
# holz1.jpg wurde in 265x215 gespeichert.
# holz2.jpg wurde in 265x215 gespeichert.
# holz3.jpg wurde in 265x215 gespeichert.
# holz4.jpg wurde in 265x215 gespeichert.
# logo.jpg wurde in 265x215 gespeichert.
# logo2.jpg wurde in 265x215 gespeichert.
# muenze.jpg wurde in 265x215 gespeichert.
# muenze2.jpg wurde in 265x215 gespeichert.
# schlussstein.jpg wurde in 265x215 gespeichert.
# schlussstein2.jpg wurde in 265x215 gespeichert.
# stories-02.jpg wurde in 265x215 gespeichert.
# stories-03.jpg wurde in 265x215 gespeichert.
# tri.jpg wurde in 265x215 gespeichert.
# barret.jpg wurde in 265x265 gespeichert.
# buch.jpg wurde in 265x265 gespeichert.
# buch2.jpg wurde in 265x265 gespeichert.
# haus.jpg wurde in 265x265 gespeichert.
# haus2.jpg wurde in 265x265 gespeichert.
# haus3.JPG wurde in 265x265 gespeichert.
# hegelhead.jpg wurde in 265x265 gespeichert.
# hegelhead2.jpeg wurde in 265x265 gespeichert.
# hegelhead3.jpg wurde in 265x265 gespeichert.
# holz1.jpg wurde in 265x265 gespeichert.
# holz2.jpg wurde in 265x265 gespeichert.
# holz3.jpg wurde in 265x265 gespeichert.
# holz4.jpg wurde in 265x265 gespeichert.
# logo.jpg wurde in 265x265 gespeichert.
# logo2.jpg wurde in 265x265 gespeichert.
# muenze.jpg wurde in 265x265 gespeichert.
# muenze2.jpg wurde in 265x265 gespeichert.
# schlussstein.jpg wurde in 265x265 gespeichert.
# schlussstein2.jpg wurde in 265x265 gespeichert.
# stories-02.jpg wurde in 265x265 gespeichert.
# stories-03.jpg wurde in 265x265 gespeichert.
# tri.jpg wurde in 265x265 gespeichert.

# %%
import os

def crawl_folder(source_folder):
    """
    Crawls a source folder and collects all file paths into a list.

    :param source_folder: The folder to crawl.
    :return: A list of file paths relative to the source folder.
    """
    file_paths = []
    
    # Walk through the directory
    for root, _, files in os.walk(source_folder):
        for file in files:
            # Get the relative path of each file
            relative_path = os.path.relpath(os.path.join(root, file), start=source_folder)
            file_paths.append(relative_path)
    
    return file_paths

if __name__ == "__main__":
    # Path to your source folder
    source_folder = "gt"
    
    if not os.path.exists(source_folder):
        print(f"Der Ordner {source_folder} existiert nicht.")
    else:
        # Crawl the folder and collect file paths
        files = crawl_folder(source_folder)
        
        # Print the result
        print("Gefundene Dateien:")
        for f in files:
            print(f)
        
        # Optionally: save or process the list of file paths
# Out:
# Gefundene Dateien:
# barret.jpg
# buch.jpg
# buch2.jpg
# haus.jpg
# haus2.jpg
# haus3.JPG
# hegelhead.jpg
# hegelhead2.jpeg
# hegelhead3.jpg
# holz1.jpg
# holz2.jpg
# holz3.jpg
# holz4.jpg
# logo.jpg
# logo2.jpg
# muenze.jpg
# muenze2.jpg
# schlussstein.jpg
# schlussstein2.jpg
# stories-02.jpg
# stories-03.jpg
# tri.jpg
# 115x115\barret.jpg
# 115x115\buch.jpg
# 115x115\buch2.jpg
# 115x115\haus.jpg
# 115x115\haus2.jpg
# 115x115\haus3.JPG
# 115x115\hegelhead.jpg
# 115x115\hegelhead2.jpeg
# 115x115\hegelhead3.jpg
# 115x115\holz1.jpg
# 115x115\holz2.jpg
# 115x115\holz3.jpg
# 115x115\holz4.jpg
# 115x115\logo.jpg
# 115x115\logo2.jpg
# 115x115\muenze.jpg
# 115x115\muenze2.jpg
# 115x115\schlussstein.jpg
# 115x115\schlussstein2.jpg
# 115x115\stories-02.jpg
# 115x115\stories-03.jpg
# 115x115\tri.jpg
# 115x165\barret.jpg
# 115x165\buch.jpg
# 115x165\buch2.jpg
# 115x165\haus.jpg
# 115x165\haus2.jpg
# 115x165\haus3.JPG
# 115x165\hegelhead.jpg
# 115x165\hegelhead2.jpeg
# 115x165\hegelhead3.jpg
# 115x165\holz1.jpg
# 115x165\holz2.jpg
# 115x165\holz3.jpg
# 115x165\holz4.jpg
# 115x165\logo.jpg
# 115x165\logo2.jpg
# 115x165\muenze.jpg
# 115x165\muenze2.jpg
# 115x165\schlussstein.jpg
# 115x165\schlussstein2.jpg
# 115x165\stories-02.jpg
# 115x165\stories-03.jpg
# 115x165\tri.jpg
# 115x215\barret.jpg
# 115x215\buch.jpg
# 115x215\buch2.jpg
# 115x215\haus.jpg
# 115x215\haus2.jpg
# 115x215\haus3.JPG
# 115x215\hegelhead.jpg
# 115x215\hegelhead2.jpeg
# 115x215\hegelhead3.jpg
# 115x215\holz1.jpg
# 115x215\holz2.jpg
# 115x215\holz3.jpg
# 115x215\holz4.jpg
# 115x215\logo.jpg
# 115x215\logo2.jpg
# 115x215\muenze.jpg
# 115x215\muenze2.jpg
# 115x215\schlussstein.jpg
# 115x215\schlussstein2.jpg
# 115x215\stories-02.jpg
# 115x215\stories-03.jpg
# 115x215\tri.jpg
# 115x265\barret.jpg
# 115x265\buch.jpg
# 115x265\buch2.jpg
# 115x265\haus.jpg
# 115x265\haus2.jpg
# 115x265\haus3.JPG
# 115x265\hegelhead.jpg
# 115x265\hegelhead2.jpeg
# 115x265\hegelhead3.jpg
# 115x265\holz1.jpg
# 115x265\holz2.jpg
# 115x265\holz3.jpg
# 115x265\holz4.jpg
# 115x265\logo.jpg
# 115x265\logo2.jpg
# 115x265\muenze.jpg
# 115x265\muenze2.jpg
# 115x265\schlussstein.jpg
# 115x265\schlussstein2.jpg
# 115x265\stories-02.jpg
# 115x265\stories-03.jpg
# 115x265\tri.jpg
# 165x115\barret.jpg
# 165x115\buch.jpg
# 165x115\buch2.jpg
# 165x115\haus.jpg
# 165x115\haus2.jpg
# 165x115\haus3.JPG
# 165x115\hegelhead.jpg
# 165x115\hegelhead2.jpeg
# 165x115\hegelhead3.jpg
# 165x115\holz1.jpg
# 165x115\holz2.jpg
# 165x115\holz3.jpg
# 165x115\holz4.jpg
# 165x115\logo.jpg
# 165x115\logo2.jpg
# 165x115\muenze.jpg
# 165x115\muenze2.jpg
# 165x115\schlussstein.jpg
# 165x115\schlussstein2.jpg
# 165x115\stories-02.jpg
# 165x115\stories-03.jpg
# 165x115\tri.jpg
# 165x165\barret.jpg
# 165x165\buch.jpg
# 165x165\buch2.jpg
# 165x165\haus.jpg
# 165x165\haus2.jpg
# 165x165\haus3.JPG
# 165x165\hegelhead.jpg
# 165x165\hegelhead2.jpeg
# 165x165\hegelhead3.jpg
# 165x165\holz1.jpg
# 165x165\holz2.jpg
# 165x165\holz3.jpg
# 165x165\holz4.jpg
# 165x165\logo.jpg
# 165x165\logo2.jpg
# 165x165\muenze.jpg
# 165x165\muenze2.jpg
# 165x165\schlussstein.jpg
# 165x165\schlussstein2.jpg
# 165x165\stories-02.jpg
# 165x165\stories-03.jpg
# 165x165\tri.jpg
# 165x215\barret.jpg
# 165x215\buch.jpg
# 165x215\buch2.jpg
# 165x215\haus.jpg
# 165x215\haus2.jpg
# 165x215\haus3.JPG
# 165x215\hegelhead.jpg
# 165x215\hegelhead2.jpeg
# 165x215\hegelhead3.jpg
# 165x215\holz1.jpg
# 165x215\holz2.jpg
# 165x215\holz3.jpg
# 165x215\holz4.jpg
# 165x215\logo.jpg
# 165x215\logo2.jpg
# 165x215\muenze.jpg
# 165x215\muenze2.jpg
# 165x215\schlussstein.jpg
# 165x215\schlussstein2.jpg
# 165x215\stories-02.jpg
# 165x215\stories-03.jpg
# 165x215\tri.jpg
# 165x265\barret.jpg
# 165x265\buch.jpg
# 165x265\buch2.jpg
# 165x265\haus.jpg
# 165x265\haus2.jpg
# 165x265\haus3.JPG
# 165x265\hegelhead.jpg
# 165x265\hegelhead2.jpeg
# 165x265\hegelhead3.jpg
# 165x265\holz1.jpg
# 165x265\holz2.jpg
# 165x265\holz3.jpg
# 165x265\holz4.jpg
# 165x265\logo.jpg
# 165x265\logo2.jpg
# 165x265\muenze.jpg
# 165x265\muenze2.jpg
# 165x265\schlussstein.jpg
# 165x265\schlussstein2.jpg
# 165x265\stories-02.jpg
# 165x265\stories-03.jpg
# 165x265\tri.jpg
# 215x115\barret.jpg
# 215x115\buch.jpg
# 215x115\buch2.jpg
# 215x115\haus.jpg
# 215x115\haus2.jpg
# 215x115\haus3.JPG
# 215x115\hegelhead.jpg
# 215x115\hegelhead2.jpeg
# 215x115\hegelhead3.jpg
# 215x115\holz1.jpg
# 215x115\holz2.jpg
# 215x115\holz3.jpg
# 215x115\holz4.jpg
# 215x115\logo.jpg
# 215x115\logo2.jpg
# 215x115\muenze.jpg
# 215x115\muenze2.jpg
# 215x115\schlussstein.jpg
# 215x115\schlussstein2.jpg
# 215x115\stories-02.jpg
# 215x115\stories-03.jpg
# 215x115\tri.jpg
# 215x165\barret.jpg
# 215x165\buch.jpg
# 215x165\buch2.jpg
# 215x165\haus.jpg
# 215x165\haus2.jpg
# 215x165\haus3.JPG
# 215x165\hegelhead.jpg
# 215x165\hegelhead2.jpeg
# 215x165\hegelhead3.jpg
# 215x165\holz1.jpg
# 215x165\holz2.jpg
# 215x165\holz3.jpg
# 215x165\holz4.jpg
# 215x165\logo.jpg
# 215x165\logo2.jpg
# 215x165\muenze.jpg
# 215x165\muenze2.jpg
# 215x165\schlussstein.jpg
# 215x165\schlussstein2.jpg
# 215x165\stories-02.jpg
# 215x165\stories-03.jpg
# 215x165\tri.jpg
# 215x215\barret.jpg
# 215x215\buch.jpg
# 215x215\buch2.jpg
# 215x215\haus.jpg
# 215x215\haus2.jpg
# 215x215\haus3.JPG
# 215x215\hegelhead.jpg
# 215x215\hegelhead2.jpeg
# 215x215\hegelhead3.jpg
# 215x215\holz1.jpg
# 215x215\holz2.jpg
# 215x215\holz3.jpg
# 215x215\holz4.jpg
# 215x215\logo.jpg
# 215x215\logo2.jpg
# 215x215\muenze.jpg
# 215x215\muenze2.jpg
# 215x215\schlussstein.jpg
# 215x215\schlussstein2.jpg
# 215x215\stories-02.jpg
# 215x215\stories-03.jpg
# 215x215\tri.jpg
# 215x265\barret.jpg
# 215x265\buch.jpg
# 215x265\buch2.jpg
# 215x265\haus.jpg
# 215x265\haus2.jpg
# 215x265\haus3.JPG
# 215x265\hegelhead.jpg
# 215x265\hegelhead2.jpeg
# 215x265\hegelhead3.jpg
# 215x265\holz1.jpg
# 215x265\holz2.jpg
# 215x265\holz3.jpg
# 215x265\holz4.jpg
# 215x265\logo.jpg
# 215x265\logo2.jpg
# 215x265\muenze.jpg
# 215x265\muenze2.jpg
# 215x265\schlussstein.jpg
# 215x265\schlussstein2.jpg
# 215x265\stories-02.jpg
# 215x265\stories-03.jpg
# 215x265\tri.jpg
# 265x115\barret.jpg
# 265x115\buch.jpg
# 265x115\buch2.jpg
# 265x115\haus.jpg
# 265x115\haus2.jpg
# 265x115\haus3.JPG
# 265x115\hegelhead.jpg
# 265x115\hegelhead2.jpeg
# 265x115\hegelhead3.jpg
# 265x115\holz1.jpg
# 265x115\holz2.jpg
# 265x115\holz3.jpg
# 265x115\holz4.jpg
# 265x115\logo.jpg
# 265x115\logo2.jpg
# 265x115\muenze.jpg
# 265x115\muenze2.jpg
# 265x115\schlussstein.jpg
# 265x115\schlussstein2.jpg
# 265x115\stories-02.jpg
# 265x115\stories-03.jpg
# 265x115\tri.jpg
# 265x165\barret.jpg
# 265x165\buch.jpg
# 265x165\buch2.jpg
# 265x165\haus.jpg
# 265x165\haus2.jpg
# 265x165\haus3.JPG
# 265x165\hegelhead.jpg
# 265x165\hegelhead2.jpeg
# 265x165\hegelhead3.jpg
# 265x165\holz1.jpg
# 265x165\holz2.jpg
# 265x165\holz3.jpg
# 265x165\holz4.jpg
# 265x165\logo.jpg
# 265x165\logo2.jpg
# 265x165\muenze.jpg
# 265x165\muenze2.jpg
# 265x165\schlussstein.jpg
# 265x165\schlussstein2.jpg
# 265x165\stories-02.jpg
# 265x165\stories-03.jpg
# 265x165\tri.jpg
# 265x215\barret.jpg
# 265x215\buch.jpg
# 265x215\buch2.jpg
# 265x215\haus.jpg
# 265x215\haus2.jpg
# 265x215\haus3.JPG
# 265x215\hegelhead.jpg
# 265x215\hegelhead2.jpeg
# 265x215\hegelhead3.jpg
# 265x215\holz1.jpg
# 265x215\holz2.jpg
# 265x215\holz3.jpg
# 265x215\holz4.jpg
# 265x215\logo.jpg
# 265x215\logo2.jpg
# 265x215\muenze.jpg
# 265x215\muenze2.jpg
# 265x215\schlussstein.jpg
# 265x215\schlussstein2.jpg
# 265x215\stories-02.jpg
# 265x215\stories-03.jpg
# 265x215\tri.jpg
# 265x265\barret.jpg
# 265x265\buch.jpg
# 265x265\buch2.jpg
# 265x265\haus.jpg
# 265x265\haus2.jpg
# 265x265\haus3.JPG
# 265x265\hegelhead.jpg
# 265x265\hegelhead2.jpeg
# 265x265\hegelhead3.jpg
# 265x265\holz1.jpg
# 265x265\holz2.jpg
# 265x265\holz3.jpg
# 265x265\holz4.jpg
# 265x265\logo.jpg
# 265x265\logo2.jpg
# 265x265\muenze.jpg
# 265x265\muenze2.jpg
# 265x265\schlussstein.jpg
# 265x265\schlussstein2.jpg
# 265x265\stories-02.jpg
# 265x265\stories-03.jpg
# 265x265\tri.jpg
